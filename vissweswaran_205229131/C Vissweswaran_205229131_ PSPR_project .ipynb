# %% [markdown]
# ## Vissweswaran C
# ## 205229131
# ##                              web scraping project

# %%
from bs4 import BeautifulSoup
from requests import get
import pandas as pd


url = 'http://www.imdb.com/search/title?release_date=2016&sort=num_votes,desc&page=1'
response = get(url)
html_soup = BeautifulSoup(response.text, 'html.parser')
movie_containers = html_soup.find_all('div', class_ = 'lister-item mode-advanced')

names = []
years = []
imdb_ratings = []
metascores = []
votes = []

for container in movie_containers:
    if container.find('div', class_ = 'ratings-metascore') is not None:
    
        name = container.h3.a.text
        names.append(name)
    
        year = container.h3.find('span', class_ = 'lister-item-year').text
        years.append(year)
    
        imdb = float(container.strong.text)
        imdb_ratings.append(imdb)
    
        m_score = container.find('span', class_ = 'metascore').text
        metascores.append(int(m_score))
    
        vote = container.find('span', attrs = {'name':'nv'})['data-value']
        votes.append(int(vote))

test_df = pd.DataFrame({'movie': names,'year': years,'imdb': imdb_ratings,'metascore': metascores,'votes': votes})
test_df.to_csv('products.csv', index=False, encoding='utf-8')
print(test_df.to_csv)
# Out:
# <bound method NDFrame.to_csv of                                       movie         year  imdb  metascore  \
# 0                                  Deadpool       (2016)   8.0         65
# 1                Captain America: Civil War       (2016)   7.8         75
# 2        Batman v Superman: Dawn of Justice       (2016)   6.4         44
# 3                             Suicide Squad       (2016)   6.0         40
# 4                            Doctor Strange       (2016)   7.5         72
# 5                                   Arrival  (II) (2016)   7.9         81
# 6                                 Rogue One       (2016)   7.8         65
# 7                                La La Land       (2016)   8.0         94
# 8                             Hacksaw Ridge       (2016)   8.1         71
# 9                                  Zootopia       (2016)   8.0         78
# 10                                    Split  (IX) (2016)   7.3         62
# 11  Fantastic Beasts and Where to Find Them       (2016)   7.3         66
# 12                        X-Men: Apocalypse       (2016)   6.9         52
# 13                               Passengers   (I) (2016)   7.0         41
# 14                      10 Cloverfield Lane       (2016)   7.2         76
# 15                            The Nice Guys       (2016)   7.4         70
# 16                                Moonlight   (I) (2016)   7.4         99
# 17                                    Moana   (I) (2016)   7.6         81
# 18                           The Accountant       (2016)   7.3         51
# 19                          The Jungle Book       (2016)   7.4         77
# 20                         Now You See Me 2       (2016)   6.5         46
# 21                    Manchester by the Sea       (2016)   7.8         96
# 22                                 Warcraft       (2016)   6.8         32
# 23                             Finding Dory       (2016)   7.3         77
# 24                        Nocturnal Animals       (2016)   7.5         67
# 25                                    Sully       (2016)   7.4         74
# 26                         Star Trek Beyond       (2016)   7.1         68
# 27                          The Conjuring 2       (2016)   7.3         65
# 28                            Don't Breathe       (2016)   7.1         71
# 29                                     Lion       (2016)   8.0         69
# 30                            Me Before You       (2016)   7.4         51
# 31                             Jason Bourne   (I) (2016)   6.6         58
# 32                             Ghostbusters       (2016)   6.5         60
# 33                       Hell or High Water  (II) (2016)   7.6         88
# 34                           Hidden Figures       (2016)   7.8         74
# 35                           Kimi no na wa.       (2016)   8.4         79
# 36                        Captain Fantastic       (2016)   7.9         72
# 37                         Assassin's Creed       (2016)   5.7         36
# 38                    The Magnificent Seven       (2016)   6.9         54
# 39                  The Secret Life of Pets       (2016)   6.5         61
# 40                                 War Dogs       (2016)   7.1         57
# 41                            Sausage Party       (2016)   6.1         66
# 42                              The Promise  (II) (2016)   6.3         49
# 43                    The Girl on the Train       (2016)   6.5         48
# 44             Independence Day: Resurgence       (2016)   5.2         32
# 45                               Busanhaeng       (2016)   7.6         72
#
#      votes
# 0   902103
# 1   663065
# 2   625289
# 3   600485
# 4   597813
# 5   593568
# 6   556127
# 7   505324
# 8   435373
# 9   433773
# 10  424343
# 11  410448
# 12  392761
# 13  349451
# 14  290277
# 15  279749
# 16  273372
# 17  272450
# 18  260067
# 19  259020
# 20  249176
# 21  246680
# 22  241572
# 23  240539
# 24  238594
# 25  237780
# 26  228022
# 27  225280
# 28  221663
# 29  213741
# 30  208875
# 31  208366
# 32  204285
# 33  203960
# 34  200657
# 35  194381
# 36  189146
# 37  185844
# 38  185111
# 39  182921
# 40  177378
# 41  175777
# 42  172702
# 43  169106
# 44  166567
# 45  165644  >
